# %%
# %load_ext lab_black

# %% [markdown]
# # Find a common destination from two different airports from historical traffic data

# %% [markdown]
# #### From two European airports, with direct flights, whatever the company

# %%
import pandas as pd
from datetime import datetime, timedelta

# %% [markdown]
# #### <br> Example with a trip from Toulouse, France (LFBO) and Amsterdam, Netherlands (EHAM), end of November

# %%
first_airport = "LFBO"
second_airport = "EHAM"

# %% [markdown]
# #### <br> Load airports and airlines table from openflights.org

# %%
airports_url = (
    "https://raw.githubusercontent.com/jpatokal/openflights/master/data/airports.dat"
)
airlines_url = (
    "https://raw.githubusercontent.com/jpatokal/openflights/master/data/airlines.dat"
)

airports_df = pd.read_csv(
    airports_url,
    header=None,
    names=[
        "id",
        "name",
        "city",
        "country",
        "iata",
        "icao",
        "lat",
        "lon",
        "alt",
        "timezone",
        "dst",
        "tz",
        "type",
        "source",
    ],
)
airlines_df = pd.read_csv(
    airlines_url,
    header=None,
    names=["id", "name", "alias", "iata", "icao", "callsign", "country", "active"],
)

# %%
def get_city(airport_icao):
    ans = airport_icao
    if not airports_df.query("icao == @airport_icao").empty:
        df = airports_df.query("icao == @airport_icao")
        ans = df.city.item() + "-" + df.name.item()
    return ans

# %%
def get_airline(airline_icao):
    ans = airline_icao
    if not airlines_df.query("icao == @airline_icao").empty:
        ans = airlines_df.query("icao == @airline_icao").name.item()
    return ans

# %% [markdown]
# #### <br> Load the so6 reference traffic file (e.g. one year before) as a pandas dataframe

# %%
my_so6_traffic_file = "my_so6_traffic_file.so6"
columns = [
    "segment_identifier",
    "flight_origin",
    "flight_destination",
    "aircraft_type",
    "time_begin",
    "time_end",
    "fl_begin",
    "fl_end",
    "status",
    "callsign",
    "date_begin",
    "date_end",
    "lat_begin",
    "lon_begin",
    "lat_end",
    "lon_end",
    "flight_identifier",
    "sequence",
    "length",
    "parity",
]

parser = lambda x, y: pd.datetime.strptime(x + y, "%y%m%d%H%M%S")

df = pd.read_csv(
    my_so6_traffic_file,
    sep=" ",
    header=None,
    names=columns,
    parse_dates={
        "datetime_begin": ["date_begin", "time_begin"],
        "datetime_end": ["date_end", "time_end"],
    },
    date_parser=parser,
)

coord_cols = ["lat_begin", "lon_begin", "lat_end", "lon_end"]
df[coord_cols] = df[coord_cols].apply(lambda x: x / 60)

t = df[
    [
        "callsign",
        "datetime_begin",
        "datetime_end",
        "flight_origin",
        "flight_destination",
        "fl_begin",
        "fl_end",
        "lat_begin",
        "lat_end",
        "lon_begin",
        "lon_end",
        "aircraft_type",
        "length",
        "flight_identifier",
    ]
]
t = t.query("flight_origin == @first_airport or flight_origin == @second_airport")
t = t.query("length > 0")  # filter null segments
t.sample(5)
# Out:
#         callsign      datetime_begin        datetime_end flight_origin  \
# 24955     DLH7KY 2018-11-23 10:57:32 2018-11-23 10:58:32          EHAM
# 169989    KLM81K 2018-11-23 09:09:30 2018-11-23 09:09:42          EHAM
# 1002013  AFR82QZ 2018-11-23 10:09:07 2018-11-23 10:09:35          LFBO
# 1172683  TAY054G 2018-11-22 23:59:34 2018-11-23 00:00:06          LFBO
# 1043954   JAI233 2018-11-23 10:59:50 2018-11-23 11:00:58          EHAM
#
#         flight_destination  fl_begin  fl_end  lat_begin    lat_end  lon_begin  \
# 24955                 EDDM       301     279  49.383611  49.293889   9.824722
# 169989                LIRF       142     150  52.176944  52.161389   5.411111
# 1002013               LFPG        25      35  43.606111  43.598889   1.392778
# 1172683               EBLG       201     192  50.374167  50.389722   3.968056
# 1043954               VIDP       256     271  52.047778  52.023611   6.535000
#
#           lon_end aircraft_type    length  flight_identifier
# 24955    9.978889          A319  8.081272          225202876
# 169989   5.446667          B737  1.607213          225200717
# 1002013  1.399167          A320  0.514619          225202353
# 1172683  4.049167          B734  3.240625          225193071
# 1043954  6.764167          B77W  8.581972          225203591

# %% [markdown]
# #### <br> Identify common destination and associated airlines

# %%
for dest in t.query("flight_origin == @first_airport").flight_destination.unique():
    second_table = t.query(
        "flight_origin == @second_airport and flight_destination == @dest"
    )
    if len(second_table.index) > 0:
        print(f"\n -> Destination {get_city(dest)}")
        first_table = t.query(
            "flight_origin == @first_airport and flight_destination == @dest"
        )
        print(f"from {get_city(first_airport)} with airlines:")
        print(set([get_airline(cs[:3]) for cs in first_table.callsign.unique()]))
        print(f"from {get_city(second_airport)} with airlines:")
        print(set([get_airline(cs[:3]) for cs in second_table.callsign.unique()]))
# Out:
# /Users/tdubot/Documents/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: `item` has been deprecated and will be removed in a future version
#   """
# /Users/tdubot/Documents/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: `item` has been deprecated and will be removed in a future version
#   after removing the cwd from sys.path.
#  -> Destination Villafranca-Verona Villafranca Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'VOLOTEA Airways'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Transavia Holland'}
#
#  -> Destination Strasbourg-Strasbourg Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'VOLOTEA Airways', 'HOP'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Air France'}
#
#  -> Destination Marseille-Marseille Provence Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'HOP'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines'}
#
#  -> Destination Rennes-Rennes-Saint-Jacques Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'HOP'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Air France'}
#
#  -> Destination Geneva-Geneva Cointrin International Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'EES', 'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'EZS', 'KLM Royal Dutch Airlines', 'easyJet'}
#
#  -> Destination Paris-Paris-Orly Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Air France', 'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Transavia France', 'Transavia Holland'}
#
#  -> Destination Paris-Charles de Gaulle International Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Atlantic Airlines', 'TNT Airways', 'Air France', 'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines', 'Federal Express', 'Air France'}
#
#  -> Destination London-London Heathrow Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'British Airways'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines', 'British Airways'}
#
#  -> Destination Nantes-Nantes Atlantique Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'HOP', 'VOLOTEA Airways', 'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Air France'}
#
#  -> Destination Munich-Munich Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Lufthansa'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'AirBridge Cargo', 'KLM Royal Dutch Airlines', 'Eurowings', 'Lufthansa', 'Transavia Holland'}
#
#  -> Destination Mulhouse-EuroAirport Basel-Mulhouse-Freiburg Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'EZS'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'EZS', 'KLM Royal Dutch Airlines', 'easyJet'}
#
#  -> Destination Brussels-Brussels Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'European Air Transport', 'BEL'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines'}
#
#  -> Destination London-London Gatwick Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'British Airways', 'easyJet'}
#
#  -> Destination Montpellier-Montpellier-Méditerranée Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'FHT'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines'}
#
#  -> Destination Berlin-Berlin-Schönefeld Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Ryanair', 'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'easyJet'}
#
#  -> Destination Madrid-Adolfo Suárez Madrid–Barajas Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Ryanair', 'Iberia Express', 'Air Nostrum'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines', 'Iberia Express', 'Air Europa'}
#
#  -> Destination Charleroi-Brussels South Charleroi Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Ryanair'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Pan Havacilik Ve Ticaret'}
#
#  -> Destination London-London Luton Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Vueling Airlines', 'easyJet'}
#
#  -> Destination Casablanca-Mohammed V International Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Royal Air Maroc'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Royal Air Maroc'}
#
#  -> Destination Venice-Venice Marco Polo Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'VOLOTEA Airways'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines', 'easyJet'}
#
#  -> Destination Prague-Václav Havel Airport Prague
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'VOLOTEA Airways'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Czech Airlines', 'KLM Royal Dutch Airlines', 'Time Air', 'easyJet'}
#
#  -> Destination Rome-Leonardo da Vinci–Fiumicino Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Alitalia', 'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Alitalia', 'KLM Royal Dutch Airlines', 'Vueling Airlines', 'easyJet'}
#
#  -> Destination Milano-Malpensa International Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines', 'Vueling Airlines', 'easyJet'}
#
#  -> Destination Sevilla-Sevilla Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Transavia Holland'}
#
#  -> Destination Lyon-Lyon Saint-Exupéry Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Star Air', 'HOP', 'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines'}
#
#  -> Destination Bristol-Bristol Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Eastern Airways', 'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines', 'easyJet'}
#
#  -> Destination Marrakech-Menara Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Royal Air Maroc', 'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Transavia Holland'}
#
#  -> Destination Dublin-Dublin Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Aer Lingus'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Ryanair', 'KLM Royal Dutch Airlines', 'Aer Lingus'}
#
#  -> Destination Lisbon-Humberto Delgado Airport (Lisbon Portela Airport)
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'TAP Portugal', 'Ryanair'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'TAP Portugal', 'KLM Royal Dutch Airlines', 'Vueling Airlines', 'Transavia Holland', 'easyJet'}
#
#  -> Destination Frankfurt-Frankfurt am Main Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Lufthansa'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines', 'Lufthansa', 'Cathay Pacific'}
#
#  -> Destination Istanbul-Atatürk International Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Turkish Airlines'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Turkish Airlines', 'KLM Royal Dutch Airlines', 'Atlasjet'}
#
#  -> Destination London-London Stansted Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Ryanair'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'easyJet'}
#
#  -> Destination Valencia-Valencia Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'TNT Airways'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines', 'Vueling Airlines', 'Transavia Holland'}
#
#  -> Destination Copenhagen-Copenhagen Kastrup Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'OYR'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Norwegian Air International (D8)', 'KLM Royal Dutch Airlines', 'Emirates', 'NJE', 'Scandinavian Airlines System'}
#
#  -> Destination Nice-Nice-Côte d'Azur Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines', 'easyJet', 'Transavia Holland'}
#
#  -> Destination Porto-Francisco de Sá Carneiro Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'easyJet'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'TAP Portugal', 'KLM Royal Dutch Airlines', 'Transavia Holland'}
#
#  -> Destination Singapore-Singapore Changi Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Singapore Airlines'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'Singapore Airlines', 'KLM Royal Dutch Airlines'}
#
#  -> Destination Humberside-Humberside Airport
# from Toulouse-Toulouse-Blagnac Airport with airlines:
# {'Eastern Airways'}
# from Amsterdam-Amsterdam Airport Schiphol with airlines:
# {'KLM Royal Dutch Airlines'}
